# %% [markdown]
# Diamond Price Prediction
# Introduction About the Data :
# The dataset The goal is to predict price of given diamond (Regression Analysis).
#
# There are 10 independent variables (including id):
#
# id : unique identifier of each diamond
# carat : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
# cut : Quality of Diamond Cut
# color : Color of Diamond
# clarity : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
# depth : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
# table : A diamond's table is the facet which can be seen when the stone is viewed face up.
# x : Diamond X dimension
# y : Diamond Y dimension
# x : Diamond Z dimension
# Target variable:
#
# price: Price of the given Diamond.
# Dataset Source Link : https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv

# %% [markdown]
# https://www.kaggle.com/code/gokulprasantht/diamond-price-prediction/notebook

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/krishnaik06/DiamondPricePrediction1/main/notebooks/data/gemstone.csv")

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
### No missing values present in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
## Dropping the Id Column
df = df.drop(labels=['id'],axis=1)

# %%
## check for duplicated records

df.duplicated().sum()
# Out:
# 0

# %%
## Segregate numerical and categorical columns

numerical_cols = df.columns[df.dtypes != 'object']
categorical_cols = df.columns[df.dtypes == 'object']
print("numerical_cols :", numerical_cols)
print("categorical_cols :",categorical_cols)
# Out:
# numerical_cols : Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# categorical_cols : Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_cols].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
print(df['cut'].unique())
print(df['cut'].nunique())
print('\n')
print(df['color'].unique())
print(df['color'].nunique())
print('\n')
print(df['clarity'].unique())
print(df['clarity'].nunique())
# Out:
# ['Premium' 'Very Good' 'Ideal' 'Good' 'Fair']
# 5
#
#
# ['F' 'J' 'G' 'E' 'D' 'H' 'I']
# 7
#
#
# ['VS2' 'SI2' 'VS1' 'SI1' 'IF' 'VVS2' 'VVS1' 'I1']
# 8

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize =(8,6))
x=0
for i in numerical_cols:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
## Plotting bar graph for catgorical values w.r.t. price

data= df.copy()
for col in categorical_cols:
    data.groupby(col)['price'].median().plot.bar()
    plt.xlabel(col)
    plt.ylabel('Price')
    plt.title(col)
    plt.show()

# %%
## Visualizing correlation between all the features

sns.heatmap(df[numerical_cols].corr(),annot=True)
# Out:
# <Axes: >

# %%
correlation = df[numerical_cols].corr()
correlation
# Out:
#           carat     depth     table         x         y         z     price
# carat  1.000000  0.027852  0.225737  0.980563  0.980161  0.974274  0.943396
# depth  0.027852  1.000000 -0.230631 -0.010762 -0.011653  0.081821  0.001880
# table  0.225737 -0.230631  1.000000  0.237578  0.233299  0.212208  0.174915
# x      0.980563 -0.010762  0.237578  1.000000  0.999109  0.989724  0.901004
# y      0.980161 -0.011653  0.233299  0.999109  1.000000  0.989527  0.901033
# z      0.974274  0.081821  0.212208  0.989724  0.989527  1.000000  0.893037
# price  0.943396  0.001880  0.174915  0.901004  0.901033  0.893037  1.000000

# %%
sampledata = df.sample(frac=0.50)
sns.pairplot(sampledata)
# Out:
# d:\MLProjects\DiamondPricePrediction\venv\lib\site-packages\seaborn-0.12.2-py3.8.egg\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# df.drop(labels=['x','y','z'],axis=1)
## currently not executing ,just to see the overfitting problem

# %%
## Now dealing with the categorical fetaures encoding

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map = {"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map ={"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map={"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}

# %%
df['cut'].map(cut_map)
# Out:
# 0         4
# 1         3
# 2         5
# 3         5
# 4         4
#          ..
# 193568    5
# 193569    4
# 193570    3
# 193571    3
# 193572    2
# Name: cut, Length: 193573, dtype: int64

# %%
df['color'].map(color_map)
# Out:
# 0         3
# 1         7
# 2         4
# 3         4
# 4         4
#          ..
# 193568    1
# 193569    4
# 193570    3
# 193571    1
# 193572    2
# Name: color, Length: 193573, dtype: int64

# %%
df['clarity'].map(clarity_map)
# Out:
# 0         4
# 1         2
# 2         5
# 3         5
# 4         4
#          ..
# 193568    6
# 193569    6
# 193570    3
# 193571    3
# 193572    2
# Name: clarity, Length: 193573, dtype: int64

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
